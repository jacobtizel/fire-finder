# %%
fire_dir = "BoWFireDataset/dataset/img"

import matplotlib.pyplot as plt
from PIL import Image
import os
import numpy as np
import cv2 as cv

image_path = os.path.join(fire_dir, os.listdir(fire_dir)[0])  
img = cv.imread(image_path, cv.IMREAD_GRAYSCALE)
img = cv.equalizeHist(img)

plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title(f'Fire Image Example ({os.path.basename(image_path)})')
plt.show()

# Print image format information
print(f"Image format: {img.format}")
print(f"Image size: {img.size}")
print(f"Image mode: {img.mode}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 20
#      17 plt.show()
#      19 # Print image format information
# ---> 20 print(f"Image format: {img.format}")
#      21 print(f"Image size: {img.size}")
#      22 print(f"Image mode: {img.mode}")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'format'
